# %% [markdown]
# # Exploratory Data Analysis (EDA)
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = "./data/sensor.csv"

# %%
df = pd.read_csv(data_path, index_col=0)

# %%
df.head()
# Out:
#              timestamp  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_43  sensor_44  \
# 0   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 1   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 2   73.54598   13.32465   16.03733   15.61777  ...   41.66666  39.351852
# 3   76.98898   13.31742   16.24711   15.69734  ...   40.88541  39.062500
# 4   76.58897   13.35359   16.21094   15.69734  ...   41.40625  38.773150
#
# ...

# %%
df.describe()
# Out:
#            sensor_00      sensor_01      sensor_02      sensor_03  \
# count  210112.000000  219951.000000  220301.000000  220301.000000
# mean        2.372221      47.591611      50.867392      43.752481
# std         0.412227       3.296666       3.666820       2.418887
# min         0.000000       0.000000      33.159720      31.640620
# 25%         2.438831      46.310760      50.390620      42.838539
# 50%         2.456539      48.133678      51.649300      44.227428
# 75%         2.499826      49.479160      52.777770      45.312500
# max         2.549016      56.727430      56.032990      48.220490
#
#            sensor_04      sensor_05      sensor_06      sensor_07  \
# count  220301.000000  220301.000000  215522.000000  214869.000000
# mean      590.673936      73.396414      13.501537      15.843152
# std       144.023912      17.298247       2.163736       2.201155
# min         2.798032       0.000000       0.014468       0.000000
# ...

# %% [markdown]
# ### Dataset General Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 220320 entries, 0 to 220319
# Data columns (total 54 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   timestamp       220320 non-null  object
#  1   sensor_00       210112 non-null  float64
#  2   sensor_01       219951 non-null  float64
#  3   sensor_02       220301 non-null  float64
#  4   sensor_03       220301 non-null  float64
#  5   sensor_04       220301 non-null  float64
#  6   sensor_05       220301 non-null  float64
#  7   sensor_06       215522 non-null  float64
#  8   sensor_07       214869 non-null  float64
#  9   sensor_08       215213 non-null  float64
#  10  sensor_09       215725 non-null  float64
#  11  sensor_10       220301 non-null  float64
#  12  sensor_11       220301 non-null  float64
#  13  sensor_12       220301 non-null  float64
#  14  sensor_13       220301 non-null  float64
#  15  sensor_14       220299 non-null  float64
# ...

# %%
# Convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp']
# Out:
# 0        2018-04-01 00:00:00
# 1        2018-04-01 00:01:00
# 2        2018-04-01 00:02:00
# 3        2018-04-01 00:03:00
# 4        2018-04-01 00:04:00
#                  ...
# 220315   2018-08-31 23:55:00
# 220316   2018-08-31 23:56:00
# 220317   2018-08-31 23:57:00
# 220318   2018-08-31 23:58:00
# 220319   2018-08-31 23:59:00
# Name: timestamp, Length: 220320, dtype: datetime64[ns]

# %%
df["machine_status"].value_counts()
# Out:
# machine_status
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: count, dtype: int64

# %% [markdown]
# The dataset consists of **220,320 rows** and **54 columns**.
# The columns are as follows:
# - 52 features corresponding to 52 sensors installed on a pump.
# - 1 target variable indicating the pump's status (`NORMAL`, `RECOVERING` or `BROKEN`).
# - 1 column indicating the time of the measurement.

# %% [markdown]
# ### Remove Duplicates

# %%
df = df.drop_duplicates()
print(f"Number of rows after dropping duplicates: {df.shape[0]}")
# Out:
# Number of rows after dropping duplicates: 220320

# %% [markdown]
# ### Missing Values
#
# We calculate the percentage of missing values in each column and show them in descending order.

# %%
# Calculate percentage of missing values
mis_val_percentage = df.isnull().sum() / len(df) * 100
mis_val_percentage = mis_val_percentage[mis_val_percentage > 0]
mis_val_percentage = mis_val_percentage.sort_values(ascending=False)
mis_val_percentage = round(mis_val_percentage, 4)
# Convert to DataFrame
mis_val_percentage_df = pd.DataFrame(mis_val_percentage)
mis_val_percentage_df.reset_index(inplace=True)
mis_val_percentage_df.columns = ["Feature", "Missing Values (%)"]

mis_val_percentage_df
# Out:
#       Feature  Missing Values (%)
# 0   sensor_15            100.0000
# 1   sensor_50             34.9569
# 2   sensor_51              6.9821
# 3   sensor_00              4.6333
# 4   sensor_07              2.4741
# 5   sensor_08              2.3180
# 6   sensor_06              2.1777
# 7   sensor_09              2.0856
# 8   sensor_01              0.1675
# 9   sensor_30              0.1185
# 10  sensor_29              0.0327
# 11  sensor_32              0.0309
# 12  sensor_18              0.0209
# 13  sensor_17              0.0209
# 14  sensor_22              0.0186
# 15  sensor_25              0.0163
# 16  sensor_16              0.0141
# 17  sensor_41              0.0123
# 18  sensor_39              0.0123
# 19  sensor_40              0.0123
# 20  sensor_42              0.0123
# 21  sensor_38              0.0123
# 22  sensor_43              0.0123
# 23  sensor_44              0.0123
# 24  sensor_45              0.0123
# 25  sensor_46              0.0123
# ...

# %% [markdown]
# We can see that only 2 features or sensors have a significant amount of missing values.
# - `sensor_15`: which has 100% missing values.
# - `sensor_50`: which has 34.96% missing values.
#
# It is evident that `sensor_15` is not useful for our analysis, and we can drop it.
# Although `sensor_50` has much less missing data, it is still significant compared to the rest of the features, which have less than 7%. Therefore, we decide to drop it as well.

# %%
# Drop columns with more than 30% missing values
threshold = 30
missing_columns = mis_val_percentage[mis_val_percentage > threshold].index
df = df.drop(columns=missing_columns)
print(f"Columns with more than {threshold}% missing values dropped: {missing_columns.tolist()}")
# Out:
# Columns with more than 30% missing values dropped: ['sensor_15', 'sensor_50']

# %% [markdown]
# For the rest of the features, we could fill the missing values with the mean of each feature. However, since the goal of this study is outlier detection, we will drop the rows with missing values to avoid introducing synthetic data that could affect the results of our analysis.

# %%
# Drop missing values
df = df.dropna()
# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)
print(f"Number of rows after dropping missing values: {df.shape[0]}")
# Out:
# Number of rows after dropping missing values: 195815

# %% [markdown]
# ### Correlation Status-Sensor
#
# By plotting the sensor's readings against the pump's status when it is `BROKEN`, we can see how the sensors behave when the pump is broken.
#
# We just plot a few sensors for illustration purposes.

# %%
# Set the 'timestamp' column as the index
df.set_index('timestamp', inplace=True)
df.head()
# Out:
#                      sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# timestamp
# 2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#                      sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# timestamp
# 2018-04-01 00:00:00   76.45975   13.41146   16.13136   15.56713   15.05353
# 2018-04-01 00:01:00   76.45975   13.41146   16.13136   15.56713   15.05353
# 2018-04-01 00:02:00   73.54598   13.32465   16.03733   15.61777   15.01013
# 2018-04-01 00:03:00   76.98898   13.31742   16.24711   15.69734   15.08247
# 2018-04-01 00:04:00   76.58897   13.35359   16.21094   15.69734   15.08247
#
# ...

# %%
# Extract the readings from the BROKEN state of the pump
broken = df[df['machine_status']=='BROKEN']
# Extract the names of the numerical columns
df2 = df.drop(['machine_status'], axis=1)
names=df2.columns
# Plot time series for each sensor with BROKEN state marked with X in red color
for name in names[0:4]:
    _ = plt.figure(figsize=(15,3))
    _ = plt.plot(df[name], color='blue')
    _ = plt.plot(broken[name], linestyle='none', marker='X', color='red', markersize=8)
    _ = plt.title(name)
    plt.show()

# %% [markdown]
# We can see, especially in `sensor_00`, that the sensors have different behaviors when the pump is broken.

# %% [markdown]
# ### Dimensionality Reduction
#
# We will use **PCA** to reduce the dimensionality of the dataset.
# PCA (Principal Component Analysis) is a technique used to reduce the dimensionality of a dataset while preserving as much variance as possible. It does this by transforming the original features into a new set of uncorrelated features called principal components.
#
# Moreover, by using PCA to transform the 52 sensors into just 2 components, we will be analyzing the data at the level of the overall functioning of the pump rather than focusing on the individual sensors.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = df.drop(['machine_status'], axis=1)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Create a DataFrame with PCA results
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

# Add the machine status to the PCA DataFrame
pca_df['machine_status'] = df['machine_status'].values

# Plot PCA results
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='machine_status', palette='Set1')
plt.title('PCA of Sensor Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Machine Status')
plt.show()

# %%
pca_df
# Out:
#              PC1       PC2 machine_status
# 0      -0.028538  0.221545         NORMAL
# 1      -0.028538  0.221545         NORMAL
# 2       0.118358  0.215548         NORMAL
# 3       0.120071  0.310433         NORMAL
# 4       0.082436  0.397295         NORMAL
# ...          ...       ...            ...
# 195810  2.212494  2.071996         NORMAL
# 195811  2.212666  2.106334         NORMAL
# 195812  2.228463  2.112883         NORMAL
# 195813  2.118543  2.134511         NORMAL
# 195814  2.161047  2.127596         NORMAL
#
# [195815 rows x 3 columns]
